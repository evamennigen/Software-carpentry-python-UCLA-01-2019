# %% [markdown]
# # Python intro

# %% [markdown]
# ## smaller heading
# * https://ucla-data-archive.github.io/2019-01-09-ucla/

# %% [markdown]
# ### smaller heading

# %% [markdown]
# * you can export jupyter notebooks and run as python code locally; markdowns will be commented
# * whos shows you the workspace
# * tidy data: a module for data organization
# * slicing = subsetting = subscripting

# %%
3*4
# Out:
# 12

# %%
x = 6 * 7 + 12
print(x)
# Out:
# 54

# %% [markdown]
# $\sum_{i=1}^{N} 2^{-i} \approx 1$

# %%
age = 42
first_name = 'Ahmed'

# %%
print(age)
# Out:
# 42

# %%
print(first_name, 'is', age, 'years old')
# Out:
# Ahmed is 42 years old

# %%
whos
# Out:
# Variable     Type    Data/Info
# ------------------------------
# age          int     42
# first_name   str     Ahmed
# x            int     54

# %%
age = age + 3

# %%
whos
# Out:
# Variable     Type    Data/Info
# ------------------------------
# age          int     45
# first_name   str     Ahmed
# x            int     54

# %%
atom_name = 'helium'
print(atom_name[0])
# Out:
# h

# %%
import math as m
print('pi is', m.pi)
# Out:
# pi is 3.141592653589793

# %% [markdown]
# # pandas is a handy library for data frames, spreadsheets etc.
# you can easily import all sorts of data

# %%
import pandas

# %%
data = pandas.read_csv('/Users/evamennigen/Desktop/data/gapminder_gdp_oceania.csv')

# %%
whos
# Out:
# Variable     Type         Data/Info
# -----------------------------------
# a            int          123
# age          int          45
# atom_name    str          helium
# data         DataFrame           country  gdpPercap<...>44  \n1     25185.00911
# first_name   str          Ahmed
# m            module       <module 'math' from '/Use<...>h.cpython-36m-darwin.so'>
# math         module       <module 'math' from '/Use<...>h.cpython-36m-darwin.so'>
# pandas       module       <module 'pandas' from '/U<...>ages/pandas/__init__.py'>
# x            int          54
# y            list         n=5

# %%
print(data)
# Out:
#        country  gdpPercap_1952  gdpPercap_1957  gdpPercap_1962  \
# 0    Australia     10039.59564     10949.64959     12217.22686
# 1  New Zealand     10556.57566     12247.39532     13175.67800
#
#    gdpPercap_1967  gdpPercap_1972  gdpPercap_1977  gdpPercap_1982  \
# 0     14526.12465     16788.62948     18334.19751     19477.00928
# 1     14463.91893     16046.03728     16233.71770     17632.41040
#
#    gdpPercap_1987  gdpPercap_1992  gdpPercap_1997  gdpPercap_2002  \
# 0     21888.88903     23424.76683     26997.93657     30687.75473
# 1     19007.19129     18363.32494     21050.41377     23189.80135
#
#    gdpPercap_2007
# 0     34435.36744
# 1     25185.00911

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2 entries, 0 to 1
# Data columns (total 13 columns):
# country           2 non-null object
# gdpPercap_1952    2 non-null float64
# gdpPercap_1957    2 non-null float64
# gdpPercap_1962    2 non-null float64
# gdpPercap_1967    2 non-null float64
# gdpPercap_1972    2 non-null float64
# gdpPercap_1977    2 non-null float64
# gdpPercap_1982    2 non-null float64
# gdpPercap_1987    2 non-null float64
# gdpPercap_1992    2 non-null float64
# gdpPercap_1997    2 non-null float64
# gdpPercap_2002    2 non-null float64
# gdpPercap_2007    2 non-null float64
# dtypes: float64(12), object(1)
# memory usage: 288.0+ bytes

# %%
print(data.columns)
# Out:
# Index(['country', 'gdpPercap_1952', 'gdpPercap_1957', 'gdpPercap_1962',
#        'gdpPercap_1967', 'gdpPercap_1972', 'gdpPercap_1977', 'gdpPercap_1982',
#        'gdpPercap_1987', 'gdpPercap_1992', 'gdpPercap_1997', 'gdpPercap_2002',
#        'gdpPercap_2007'],
#       dtype='object')

# %%
new_data = data.T #transponses the data

# %% [markdown]
# # note that there's a difference b/w print(data.describe) and print(data.describe()) - you want the latter one

# %%
print(data.describe)
# Out:
# <bound method NDFrame.describe of        country  gdpPercap_1952  gdpPercap_1957  gdpPercap_1962  \
# 0    Australia     10039.59564     10949.64959     12217.22686
# 1  New Zealand     10556.57566     12247.39532     13175.67800
#
#    gdpPercap_1967  gdpPercap_1972  gdpPercap_1977  gdpPercap_1982  \
# 0     14526.12465     16788.62948     18334.19751     19477.00928
# 1     14463.91893     16046.03728     16233.71770     17632.41040
#
#    gdpPercap_1987  gdpPercap_1992  gdpPercap_1997  gdpPercap_2002  \
# 0     21888.88903     23424.76683     26997.93657     30687.75473
# 1     19007.19129     18363.32494     21050.41377     23189.80135
#
#    gdpPercap_2007
# 0     34435.36744
# 1     25185.00911  >

# %%
print(data.describe())
# Out:
#        gdpPercap_1952  gdpPercap_1957  gdpPercap_1962  gdpPercap_1967  \
# count        2.000000        2.000000        2.000000        2.000000
# mean     10298.085650    11598.522455    12696.452430    14495.021790
# std        365.560078      917.644806      677.727301       43.986086
# min      10039.595640    10949.649590    12217.226860    14463.918930
# 25%      10168.840645    11274.086022    12456.839645    14479.470360
# 50%      10298.085650    11598.522455    12696.452430    14495.021790
# 75%      10427.330655    11922.958888    12936.065215    14510.573220
# max      10556.575660    12247.395320    13175.678000    14526.124650
#
#        gdpPercap_1972  gdpPercap_1977  gdpPercap_1982  gdpPercap_1987  \
# count         2.00000        2.000000        2.000000        2.000000
# mean      16417.33338    17283.957605    18554.709840    20448.040160
# std         525.09198     1485.263517     1304.328377     2037.668013
# ...

# %%
new_data.to_csv('/Users/evamennigen/Desktop/data/transposed_data.csv')

# %%
data = pandas.read_csv('/Users/evamennigen/Desktop/data/gapminder_gdp_europe.csv', index_col = 'country')

# %%
print(data.describe())
# Out:
#        gdpPercap_1952  gdpPercap_1957  gdpPercap_1962  gdpPercap_1967  \
# count       30.000000       30.000000       30.000000       30.000000
# mean      5661.057435     6963.012816     8365.486814    10143.823757
# std       3114.060493     3677.950146     4199.193906     4724.983889
# min        973.533195     1353.989176     1709.683679     2172.352423
# 25%       3241.132406     4394.874315     5373.536612     6657.939047
# 50%       5142.469716     6066.721495     7515.733738     9366.067033
# 75%       7236.794919     9597.220820    10931.085347    13277.182057
# max      14734.232750    17909.489730    20431.092700    22966.144320
#
#        gdpPercap_1972  gdpPercap_1977  gdpPercap_1982  gdpPercap_1987  \
# count       30.000000       30.000000       30.000000       30.000000
# mean     12479.575246    14283.979110    15617.896551    17214.310727
# std       5509.691411     5874.464896     6453.234827     7482.957960
# ...

# %%
data
# Out:
#                         gdpPercap_1952  gdpPercap_1957  gdpPercap_1962  \
# country
# Albania                    1601.056136     1942.284244     2312.888958
# Austria                    6137.076492     8842.598030    10750.721110
# Belgium                    8343.105127     9714.960623    10991.206760
# Bosnia and Herzegovina      973.533195     1353.989176     1709.683679
# Bulgaria                   2444.286648     3008.670727     4254.337839
# Croatia                    3119.236520     4338.231617     5477.890018
# Czech Republic             6876.140250     8256.343918    10136.867130
# Denmark                    9692.385245    11099.659350    13583.313510
# Finland                    6424.519071     7545.415386     9371.842561
# France                     7029.809327     8662.834898    10560.485530
# Germany                    7144.114393    10187.826650    12902.462910
# Greece                     3530.690067     4916.299889     6017.190733
# ...

# %%
print(data.iloc[-1,-1])
# Out:
# 33203.26128

# %%
print(data.loc["Albania",:])
# Out:
# gdpPercap_1952    1601.056136
# gdpPercap_1957    1942.284244
# gdpPercap_1962    2312.888958
# gdpPercap_1967    2760.196931
# gdpPercap_1972    3313.422188
# gdpPercap_1977    3533.003910
# gdpPercap_1982    3630.880722
# gdpPercap_1987    3738.932735
# gdpPercap_1992    2497.437901
# gdpPercap_1997    3193.054604
# gdpPercap_2002    4604.211737
# gdpPercap_2007    5937.029526
# Name: Albania, dtype: float64

# %%
print(data.loc[:,"gdpPercap_1982"])
# Out:
# country
# Albania                    3630.880722
# Austria                   21597.083620
# Belgium                   20979.845890
# Bosnia and Herzegovina     4126.613157
# Bulgaria                   8224.191647
# Croatia                   13221.821840
# Czech Republic            15377.228550
# Denmark                   21688.040480
# Finland                   18533.157610
# France                    20293.897460
# Germany                   22031.532740
# Greece                    15268.420890
# Hungary                   12545.990660
# Iceland                   23269.607500
# Ireland                   12618.321410
# Italy                     16537.483500
# Montenegro                11222.587620
# Netherlands               21399.460460
# Norway                    26298.635310
# Poland                     8451.531004
# Portugal                  11753.842910
# Romania                    9605.314053
# Serbia                    15181.092700
# Slovak Republic           11348.545850
# ...

# %%
print(data.loc['Hungary':'Poland','gdpPercap_1962':'gdpPercap_1987'].max())
# Out:
# gdpPercap_1962    13450.40151
# gdpPercap_1967    16361.87647
# gdpPercap_1972    18965.05551
# gdpPercap_1977    23311.34939
# gdpPercap_1982    26298.63531
# gdpPercap_1987    31540.97480
# dtype: float64

# %%
subset_europe = data.loc['Hungary':'Poland','gdpPercap_1962':'gdpPercap_1987']

# %%
subset_europe
# Out:
#              gdpPercap_1962  gdpPercap_1967  gdpPercap_1972  gdpPercap_1977  \
# country
# Hungary         7550.359877     9326.644670    10168.656110    11674.837370
# Iceland        10350.159060    13319.895680    15798.063620    19654.962470
# Ireland         6631.597314     7655.568963     9530.772896    11150.981130
# Italy           8243.582340    10022.401310    12269.273780    14255.984750
# Montenegro      4649.593785     5907.850937     7778.414017     9595.929905
# Netherlands    12790.849560    15363.251360    18794.745670    21209.059200
# Norway         13450.401510    16361.876470    18965.055510    23311.349390
# Poland          5338.752143     6557.152776     8006.506993     9508.141454
#
#              gdpPercap_1982  gdpPercap_1987
# country
# Hungary        12545.990660    12986.479980
# Iceland        23269.607500    26923.206280
# Ireland        12618.321410    13872.866520
# Italy          16537.483500    19207.234820
# ...

# %%
print('What values are very big?', subset_europe > 10000)
# Out:
# What values are very big?              gdpPercap_1962  gdpPercap_1967  gdpPercap_1972  gdpPercap_1977  \
# country
# Hungary               False           False            True            True
# Iceland                True            True            True            True
# Ireland               False           False           False            True
# Italy                 False            True            True            True
# Montenegro            False           False           False           False
# Netherlands            True            True            True            True
# Norway                 True            True            True            True
# Poland                False           False           False           False
#
#              gdpPercap_1982  gdpPercap_1987
# country
# Hungary                True            True
# Iceland                True            True
# Ireland                True            True
# Italy                  True            True
# ...

# %%
mask_higher = data.apply(lambda x:x>x.mean())
wealth_score = mask_higher.aggregate('sum', axis = 1)/len(data.columns)
print(wealth_score)
# Out:
# country
# Albania                   0.000000
# Austria                   1.000000
# Belgium                   1.000000
# Bosnia and Herzegovina    0.000000
# Bulgaria                  0.000000
# Croatia                   0.000000
# Czech Republic            0.500000
# Denmark                   1.000000
# Finland                   1.000000
# France                    1.000000
# Germany                   1.000000
# Greece                    0.333333
# Hungary                   0.000000
# Iceland                   1.000000
# Ireland                   0.333333
# Italy                     0.500000
# Montenegro                0.000000
# Netherlands               1.000000
# Norway                    1.000000
# Poland                    0.000000
# Portugal                  0.000000
# Romania                   0.000000
# Serbia                    0.000000
# Slovak Republic           0.000000
# Slovenia                  0.333333
# Spain                     0.333333
# ...

# %%
data
# Out:
#                         gdpPercap_1952  gdpPercap_1957  gdpPercap_1962  \
# country
# Albania                    1601.056136     1942.284244     2312.888958
# Austria                    6137.076492     8842.598030    10750.721110
# Belgium                    8343.105127     9714.960623    10991.206760
# Bosnia and Herzegovina      973.533195     1353.989176     1709.683679
# Bulgaria                   2444.286648     3008.670727     4254.337839
# Croatia                    3119.236520     4338.231617     5477.890018
# Czech Republic             6876.140250     8256.343918    10136.867130
# Denmark                    9692.385245    11099.659350    13583.313510
# Finland                    6424.519071     7545.415386     9371.842561
# France                     7029.809327     8662.834898    10560.485530
# Germany                    7144.114393    10187.826650    12902.462910
# Greece                     3530.690067     4916.299889     6017.190733
# ...

# %%
# GDP per capita for all countries in 1982.
print(data.loc[:,'gdpPercap_1982'])
# Out:
# country
# Albania                    3630.880722
# Austria                   21597.083620
# Belgium                   20979.845890
# Bosnia and Herzegovina     4126.613157
# Bulgaria                   8224.191647
# Croatia                   13221.821840
# Czech Republic            15377.228550
# Denmark                   21688.040480
# Finland                   18533.157610
# France                    20293.897460
# Germany                   22031.532740
# Greece                    15268.420890
# Hungary                   12545.990660
# Iceland                   23269.607500
# Ireland                   12618.321410
# Italy                     16537.483500
# Montenegro                11222.587620
# Netherlands               21399.460460
# Norway                    26298.635310
# Poland                     8451.531004
# Portugal                  11753.842910
# Romania                    9605.314053
# Serbia                    15181.092700
# Slovak Republic           11348.545850
# ...

# %%
# GDP per capita for Denmark for all years.
print(data.loc['Denmark',:])
# Out:
# gdpPercap_1952     9692.385245
# gdpPercap_1957    11099.659350
# gdpPercap_1962    13583.313510
# gdpPercap_1967    15937.211230
# gdpPercap_1972    18866.207210
# gdpPercap_1977    20422.901500
# gdpPercap_1982    21688.040480
# gdpPercap_1987    25116.175810
# gdpPercap_1992    26406.739850
# gdpPercap_1997    29804.345670
# gdpPercap_2002    32166.500060
# gdpPercap_2007    35278.418740
# Name: Denmark, dtype: float64

# %%
# GDP per capita for all countries for years after 1985
print(data.loc[:,'gdpPercap_1985':])
# Out:
#                         gdpPercap_1987  gdpPercap_1992  gdpPercap_1997  \
# country
# Albania                    3738.932735     2497.437901     3193.054604
# Austria                   23687.826070    27042.018680    29095.920660
# Belgium                   22525.563080    25575.570690    27561.196630
# Bosnia and Herzegovina     4314.114757     2546.781445     4766.355904
# Bulgaria                   8239.854824     6302.623438     5970.388760
# Croatia                   13822.583940     8447.794873     9875.604515
# Czech Republic            16310.443400    14297.021220    16048.514240
# Denmark                   25116.175810    26406.739850    29804.345670
# Finland                   21141.012230    20647.164990    23723.950200
# France                    22066.442140    24703.796150    25889.784870
# Germany                   24639.185660    26505.303170    27788.884160
# Greece                    16120.528390    17541.496340    18747.698140
# ...

# %%
# GDP per capita for each country in 2007 as a multiple of GDP per capita for that country in 1952.
data['gdpPercap_2007']/data['gdpPercap_1952']
# Out:
# country
# Albania                   3.708196
# Austria                   5.886596
# Belgium                   4.038377
# Bosnia and Herzegovina    7.648736
# Bulgaria                  4.369697
# Croatia                   4.686795
# Czech Republic            3.320658
# Denmark                   3.639808
# Finland                   5.168805
# France                    4.334402
# Germany                   4.503060
# Greece                    7.799725
# Hungary                   3.421364
# Iceland                   4.978308
# Ireland                   7.806873
# Italy                     5.793425
# Montenegro                3.495221
# Netherlands               4.115376
# Norway                    4.889067
# Poland                    3.819475
# Portugal                  6.684325
# Romania                   3.437140
# Serbia                    2.732555
# Slovak Republic           3.680703
# Slovenia                  6.113405
# Spain                     7.517163
# ...

# %%
# %matplotlib inline

# %%
import matplotlib.pyplot as plt

# %%
time = [0, 1, 2, 3]
position = [0, 100, 200, 300]
plt.plot(time, position)
plt.xlabel('Time (hour)')
plt.ylabel('Position (km)')
# Out:
# Text(0, 0.5, 'Position (km)')

# %%
whos
# Out:
# Variable        Type         Data/Info
# --------------------------------------
# a               int          123
# age             int          45
# atom_name       str          helium
# data            DataFrame                            g<...>.999190    33203.261280
# first_name      str          Ahmed
# m               module       <module 'math' from '/Use<...>h.cpython-36m-darwin.so'>
# mask_higher     DataFrame                            g<...>   True            True
# math            module       <module 'math' from '/Use<...>h.cpython-36m-darwin.so'>
# new_data        DataFrame                            0<...>7    34435.4        25185
# pandas          module       <module 'pandas' from '/U<...>ages/pandas/__init__.py'>
# plt             module       <module 'matplotlib.pyplo<...>es/matplotlib/pyplot.py'>
# position        list         n=4
# subset_europe   DataFrame                 gdpPercap_19<...>.531004     9082.351172
# time            list         n=4
# ...

# %%
data = pandas.read_csv('/Users/evamennigen/Desktop/data/gapminder_gdp_oceania.csv', index_col = 'country') 
# you can also use a numerical index to tell which column is the index column
# data = pandas.read_csv('/Users/evamennigen/Desktop/data/gapminder_gdp_oceania.csv', index_col = 0)

# %%
data
# Out:
#              gdpPercap_1952  gdpPercap_1957  gdpPercap_1962  gdpPercap_1967  \
# country
# Australia       10039.59564     10949.64959     12217.22686     14526.12465
# New Zealand     10556.57566     12247.39532     13175.67800     14463.91893
#
#              gdpPercap_1972  gdpPercap_1977  gdpPercap_1982  gdpPercap_1987  \
# country
# Australia       16788.62948     18334.19751     19477.00928     21888.88903
# New Zealand     16046.03728     16233.71770     17632.41040     19007.19129
#
#              gdpPercap_1992  gdpPercap_1997  gdpPercap_2002  gdpPercap_2007
# country
# Australia       23424.76683     26997.93657     30687.75473     34435.36744
# New Zealand     18363.32494     21050.41377     23189.80135     25185.00911

# %%
years = data.columns.str.strip('gdpPercap_')

# %%
# but years is still a string variable
data.columns = years.astype(int)

# %%
data.loc['Australia'].plot()

# %%
data.T.plot()

# %%
plt.style.use('ggplot')
data.T.plot(kind = 'bar')

# %%
plt.savefig('/Users/evamennigen/Desktop/data/example.png')

# %%
gdp_australia = data.loc['Australia']
gdp_nz = data.loc['New Zealand']
plt.plot(years,gdp_australia, 'b--', label = 'Australia')
plt.plot(years,gdp_nz, 'g--', label = 'NZ')
plt.legend(loc = 'upper left')

# %%
plt.scatter(gdp_australia,gdp_nz)
